# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df_hargarumah = pd.read_csv('harga_rumah.csv',
                      names=['harga','luas','kasur','km'])
                            
df_hargarumah
# Out:
#         harga  luas  kasur  km
# 0       harga  luas  kasur  km
# 1    13300000  7420      4   2
# 2    12250000  8960      4   4
# 3    12250000  9960      3   2
# 4    12215000  7500      4   2
# ..        ...   ...    ...  ..
# 541   1820000  3000      2   1
# 542   1767150  2400      3   1
# 543   1750000  3620      2   1
# 544   1750000  2910      3   1
# 545   1750000  3850      3   1
#
# [546 rows x 4 columns]

# %%
df_hargarumah.drop([0], inplace=True)
df_hargarumah.head()
# Out:
#       harga  luas kasur km
# 1  13300000  7420     4  2
# 2  12250000  8960     4  4
# 3  12250000  9960     3  2
# 4  12215000  7500     4  2
# 5  11410000  7420     4  1

# %%
df_hargarumah.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 545 entries, 1 to 545
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   harga   545 non-null    object
#  1   luas    545 non-null    object
#  2   kasur   545 non-null    object
#  3   km      545 non-null    object
# dtypes: object(4)
# memory usage: 21.3+ KB

# %%
df_hargarumah['luas']=df_hargarumah.luas.astype(int)
df_hargarumah['kasur']=df_hargarumah.kasur.astype(int)
df_hargarumah['km']=df_hargarumah.km.astype(int)
df_hargarumah['harga']=df_hargarumah.harga.astype(int)

# %%
df_hargarumah.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 545 entries, 1 to 545
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   harga   545 non-null    object
#  1   luas    545 non-null    int32
#  2   kasur   545 non-null    int32
#  3   km      545 non-null    int32
# dtypes: int32(3), object(1)
# memory usage: 14.9+ KB

# %%
df_hargarumah.shape
# Out:
# (545, 4)

# %%
train = df_hargarumah[500:]
test = df_hargarumah[:500]

# %%
print(train.shape)
print(test.shape)
# Out:
# (45, 4)
# (500, 4)

# %%
X_train = train[['luas','kasur','km']]
y_train = train['harga']

# %%
linreg = LinearRegression()
linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(linreg.coef_)
print(linreg.intercept_)
# Out:
# [ 4.90803777e+01 -5.52794320e+04  2.19955322e+05]
# 2054189.4653932587

# %% [markdown]
# y= 4.90x1 -5.52x2 +  2.19x3 + 2054189.46

# %%
X_test = test[['luas','kasur','km']]

y_test = test['harga']

# %%
pred = linreg.predict(X_test)
pred
# Out:
# array([2637158.78428856, 3152653.21037886, 2817102.37560214,
#        2641085.21450332, 2417203.46206048, 2916319.96872636,
#        2914047.34463066, 3232760.39059156, 2450578.11888593,
#        2610473.98555041, 2756167.47707182, 2787419.97020467,
#        2594458.85570305, 2444763.70376534, 2711088.75980363,
#        2347509.32574849, 2596912.87458728, 2745445.02418277,
#        2554031.55121324, 2643357.83859902, 2320333.7232335 ,
#        2679431.91619713, 2503403.53199667, 2552068.33610586,
#        2760169.13748812, 2593968.05192621, 2622744.07997154,
#        2543894.84358637, 2607891.95246639, 2542924.45913433,
#        2695137.63705617, 2451869.13542795, 2512494.62496995,
#        2840736.18709224, 2333457.41100852, 2671824.45765603,
#        2695481.19969996, 2714705.78103007, 2402788.75774345,
#        2567464.64797658, 2429782.96546992, 2640413.01593795,
#        2646302.66126009, 2567464.64797658, 2567464.64797658,
# ...

# %%
y_test
# Out:
# 1      13300000
# 2      12250000
# 3      12250000
# 4      12215000
# 5      11410000
#          ...
# 496     2730000
# 497     2695000
# 498     2660000
# 499     2660000
# 500     2660000
# Name: harga, Length: 500, dtype: int32
